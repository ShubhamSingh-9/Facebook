# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Data Set.xlsx')
df
# Out:
#     Study_id     Cell_id  Brand within 3s  Sound Off Format Platform  \
# 0          1    Ads_only                1          1  Video    FB+IG
# 1          2  Influencer                1          1  Video    FB+IG
# 2          2    Ads_only                1          1  Video    FB+IG
# 3          3  Influencer                0          0    Mix    FB+IG
# 4          3    Ads_only                0          0    Mix    FB+IG
# ..       ...         ...              ...        ...    ...      ...
# 82        13    Ads_only                1          1  Image    FB+IG
# 83        14  Influencer                1          1  Image       FB
# 84        14    Ads_only                1          1  Image       FB
# 85        15  Influencer                1          1  Image    FB+IG
# 86        15    Ads_only                1          1  Image    FB+IG
#
#       Question Type  Test Positive %  Control Positive %
# 0         ad_recall         0.153576            0.087302
# ...

# %%
group_by=df.groupby('Cell_id')
group_by

# %%
df.pivot_table(index='Cell_id', columns='Test_Positive_%')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.pivot_table(index='Cell_id', columns='Test_Positive_%')
#
# File ~\anaconda3\envs\env\lib\site-packages\pandas\core\frame.py:8731, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8714 @Substitution("")
#    8715 @Appender(_shared_docs["pivot_table"])
#    8716 def pivot_table(
#    (...)
#    8727     sort=True,
#    8728 ) -> DataFrame:
#    8729     from pandas.core.reshape.pivot import pivot_table
# -> 8731     return pivot_table(
#    8732         self,
#    8733         values=values,
#    8734         index=index,
#    8735         columns=columns,
#    8736         aggfunc=aggfunc,
#    8737         fill_value=fill_value,
#    8738         margins=margins,
#    8739         dropna=dropna,
# ...
